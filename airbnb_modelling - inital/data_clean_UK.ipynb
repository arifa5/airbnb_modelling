# %% [markdown]
# Data cleaning for UK cities (excluding London). A model will then be created from the cleaned data and compared to the machine learning model created from solely the London data

# %% [markdown]
# # Import packages and data

# %%
import pandas as pd
import numpy as np

# %%
manchester_df= pd.read_csv("data//airbnb//listings//manchester_listings.csv")
bristol_df= pd.read_csv("data//airbnb//listings//bristol_listings.csv")
greater_manchester_df= pd.read_csv("data//airbnb//listings//greater_manchester_listings.csv")

edinburgh_df= pd.read_csv("data//airbnb//listings//edinburgh_listings.csv")
 

manchester_df['city']='Manchester'

bristol_df['city']='Bristol'

greater_manchester_df['city']='Manchester'

edinburgh_df['city']='Edinburgh'

# %%
#confirming columns are the same
column_differences_em=edinburgh_df.columns.difference(manchester_df.columns)
column_differences_eb=edinburgh_df.columns.difference(bristol_df.columns)

print("Differences in columns for Edinburgh-Manchester:", column_differences_em        
     ,"\nDifferences in clumns for edinburgh-Bristol:", column_differences_eb) #columns in all 3 dataframes are the same
# Out:
# Differences in columns for Edinburgh-Manchester: Index(['bathrooms_text', 'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'maximum_maximum_nights',
#        'maximum_minimum_nights', 'maximum_nights_avg_ntm',
#        'minimum_maximum_nights', 'minimum_minimum_nights',
#        'minimum_nights_avg_ntm', 'neighbourhood_group_cleansed',
#        'number_of_reviews_l30d', 'number_of_reviews_ltm'],
#       dtype='object')
# Differences in clumns for edinburgh-Bristol: Index([], dtype='object')

# %% [markdown]
# Differences in columns between Edinburgh and Manchester. Also Edinurgh contains some listings from new york/Australia and all sorts of other places. So we will leave out edinburgh.

# %%
column_differences_bm=manchester_df.columns.difference(bristol_df.columns)
column_differences_bm
# Out:
# Index(['bed_type', 'cancellation_policy', 'cleaning_fee', 'country',
#        'country_code', 'experiences_offered', 'extra_people',
#        'guests_included', 'is_location_exact', 'jurisdiction_names',
#        'last_searched', 'market', 'medium_url', 'monthly_price', 'notes',
#        'region_id', 'region_name', 'region_parent_id', 'region_parent_name',
#        'require_guest_phone_verification', 'require_guest_profile_picture',
#        'requires_license', 'security_deposit', 'smart_location', 'space',
#        'square_feet', 'state', 'street', 'summary', 'thumbnail_url', 'transit',
#        'weekly_price', 'xl_picture_url', 'zipcode'],
#       dtype='object')

# %%
#greater manhester and bristol missing bathroom data but has bathroom text so will take first vlaue
greater_manchester_df['bathrooms']=greater_manchester_df['bathrooms_text'].str[0:1]
bristol_df['bathrooms']=bristol_df['bathrooms_text'].str[0:1]

# %% [markdown]
# # Cleaning greater manchester wards

# %%
greater_manchester_df['neighbourhood_cleansed']=greater_manchester_df['neighbourhood_cleansed'].str.replace('District'," ")

# %%
greater_manchester_df['neighbourhood_cleansed'].unique()
# Out:
# array(['City Centre', 'Rochdale  ', 'Stockport  ', 'Ancoats and Clayton',
#        'Moss Side', 'Bradford', 'Worlsey', 'Salford  ', 'Hulme',
#        'Trafford  ', 'Chorlton', 'Didsbury West', 'Old Moat', 'Burnage',
#        'Levenshulme', 'Didsbury East', 'Withington', 'Chorlton Park',
#        'Oldham  ', 'Tameside  ', 'Sharston', 'Longsight', 'Whalley Range',
#        'Cheetham', 'Higher Blackley', 'Rusholme', 'Wigan  ', 'Ardwick',
#        'Brooklands', 'Gorton South', 'Gorton North', 'Bolton  ',
#        'Fallowfield', 'Bury  ', 'Miles Platting and Newton Heath',
#        'Northenden', 'Harpurhey', 'Crumpsall', 'Woodhouse Park', 'Moston',
#        'Baguley', 'Charlestown'], dtype=object)

# %%
#some manchester listings have given local authority(which we will be using later), therefore, I will be creating a new dataframe,concatting and removing duplicaes a tthe end

# %% [markdown]
# # Selecting the columns we want and concatting bristol and manchester dataset

# %%
manchester_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_searched', 'last_scraped',
#        'name', 'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'country_code', 'country', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'square_feet', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'calendar_updated',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'calendar_last_scraped',
#        'number_of_reviews', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'license',
#        'jurisdiction_names', 'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'region_id', 'region_name', 'region_parent_id', 'region_parent_name',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
columns=['id', 'neighbourhood_cleansed','city', 'latitude', 'longitude', 'property_type','room_type' ,'accommodates',
      'bathrooms','bedrooms','price', 'minimum_nights','maximum_nights', 'availability_365', 'number_of_reviews', 'reviews_per_month','host_is_superhost','amenities']

manchester_df=manchester_df[columns]
greater_manchester_df=greater_manchester_df[columns]
bristol_df=bristol_df[columns]

# %%
combined_df=pd.concat([manchester_df,bristol_df,greater_manchester_df])

# %%
combined_df
# Out:
#             id neighbourhood_cleansed        city   latitude  longitude  \
# 0      2613909                Burnage  Manchester  53.435477  -2.198659
# 1       753374                Burnage  Manchester  53.435642  -2.198359
# 2      8693211                Burnage  Manchester  53.426219  -2.206233
# 3      2926014                Burnage  Manchester  53.421159  -2.212176
# 4     10379829                Burnage  Manchester  53.431202  -2.206740
# ...        ...                    ...         ...        ...        ...
# 3312  46007324          Didsbury West  Manchester  53.419710  -2.241280
# 3313  46034363                 Bury    Manchester  53.606210  -2.306830
# 3314  46036608              Salford    Manchester  53.481750  -2.291190
# 3315  46036968            City Centre  Manchester  53.485450  -2.239690
# 3316  46037402             Trafford    Manchester  53.424911  -2.316742
#
#                   property_type        room_type  accommodates bathrooms  \
# 0               Bed & Breakfast     Private room             2         1
# 1                         House     Private room             2         1
# 2                         House     Private room             2         2
# 3                     Apartment     Private room             2         1
# 4                         House  Entire home/apt             8         1
# ...                         ...              ...           ...       ...
# 3312           Entire apartment  Entire home/apt             3         1
# 3313               Entire house  Entire home/apt             3         3
# 3314               Entire house  Entire home/apt             6         2
# 3315  Entire serviced apartment  Entire home/apt             2         1
# 3316              Room in hotel     Private room             2         1
#
#       bedrooms    price  minimum_nights  maximum_nights  availability_365  \
# 0          1.0   $30.00               1              14               365
# 1          1.0   $20.00               1              14                 0
# 2          1.0   $34.00               1            1125               141
# 3          1.0   $30.00               1            1125               338
# 4          3.0  $351.00               1            1125               348
# ...        ...      ...             ...             ...               ...
# 3312       2.0   $40.00               2            1125               362
# 3313       3.0  $206.00               2             365               173
# 3314       3.0   $60.00               1            1125               143
# 3315       NaN   $68.00               1             365               365
# 3316       1.0   $35.00               1            1125               365
#
#       number_of_reviews  reviews_per_month host_is_superhost  \
# 0                    23               1.04                 f
# 1                    63               1.53                 f
# 2                    16               2.54                 t
# 3                    26               1.29                 f
# 4                     1               1.00                 f
# ...                 ...                ...               ...
# 3312                  0                NaN                 f
# 3313                  0                NaN                 t
# 3314                  0                NaN                 f
# 3315                  0                NaN                 f
# 3316                  0                NaN                 f
#
#                                               amenities
# 0                                                    {}
# 1     {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 2     {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 3     {TV,"Wireless Internet",Kitchen,"Free Parking ...
# 4     {TV,Internet,"Wireless Internet",Kitchen,"Free...
# ...                                                 ...
# 3312  ["Iron", "First aid kit", "Shampoo", "Wifi", "...
# 3313  ["Hot water", "Shampoo", "Wifi", "Essentials",...
# 3314  ["Iron", "Lockbox", "Breakfast", "Wifi", "Esse...
# 3315  ["Iron", "Dryer", "Hot water", "Fire extinguis...
# 3316  ["Iron", "Shampoo", "Wifi", "Essentials", "TV"...
#
# [5774 rows x 18 columns]

# %%
#remove the dollar sign before price
combined_df['price'] = combined_df.price.str.replace("\$|,",'').astype(float)

# %% [markdown]
# # Fill in blanks

# %%
combined_df.isna().sum()
# Out:
# id                           0
# neighbourhood_cleansed       0
# city                         0
# latitude                     0
# longitude                    0
# property_type                0
# room_type                    0
# accommodates                 0
# bathrooms                   10
# bedrooms                   278
# price                        0
# minimum_nights               0
# maximum_nights               0
# availability_365             0
# number_of_reviews            0
# reviews_per_month         1182
# host_is_superhost            0
# amenities                    0
# dtype: int64

# %% [markdown]
# Need to fill in bedrooms 1, bathrooms 1, and reviews to 0

# %%
combined_df['bathrooms'].fillna(value=1,inplace=True)
combined_df['reviews_per_month'].fillna(value=0,inplace=True)

# %%
combined_df.isna().sum()
# Out:
# id                          0
# neighbourhood_cleansed      0
# city                        0
# latitude                    0
# longitude                   0
# property_type               0
# room_type                   0
# accommodates                0
# bathrooms                   0
# bedrooms                  278
# price                       0
# minimum_nights              0
# maximum_nights              0
# availability_365            0
# number_of_reviews           0
# reviews_per_month           0
# host_is_superhost           0
# amenities                   0
# dtype: int64

# %%
combined_df
# Out:
#             id neighbourhood_cleansed        city   latitude  longitude  \
# 0      2613909                Burnage  Manchester  53.435477  -2.198659
# 1       753374                Burnage  Manchester  53.435642  -2.198359
# 2      8693211                Burnage  Manchester  53.426219  -2.206233
# 3      2926014                Burnage  Manchester  53.421159  -2.212176
# 4     10379829                Burnage  Manchester  53.431202  -2.206740
# ...        ...                    ...         ...        ...        ...
# 3312  46007324          Didsbury West  Manchester  53.419710  -2.241280
# 3313  46034363                 Bury    Manchester  53.606210  -2.306830
# 3314  46036608              Salford    Manchester  53.481750  -2.291190
# 3315  46036968            City Centre  Manchester  53.485450  -2.239690
# 3316  46037402             Trafford    Manchester  53.424911  -2.316742
#
#                   property_type        room_type  accommodates bathrooms  \
# 0               Bed & Breakfast     Private room             2         1
# 1                         House     Private room             2         1
# 2                         House     Private room             2         2
# 3                     Apartment     Private room             2         1
# 4                         House  Entire home/apt             8         1
# ...                         ...              ...           ...       ...
# 3312           Entire apartment  Entire home/apt             3         1
# 3313               Entire house  Entire home/apt             3         3
# 3314               Entire house  Entire home/apt             6         2
# 3315  Entire serviced apartment  Entire home/apt             2         1
# 3316              Room in hotel     Private room             2         1
#
#       bedrooms  price  minimum_nights  maximum_nights  availability_365  \
# 0          1.0   30.0               1              14               365
# 1          1.0   20.0               1              14                 0
# 2          1.0   34.0               1            1125               141
# 3          1.0   30.0               1            1125               338
# 4          3.0  351.0               1            1125               348
# ...        ...    ...             ...             ...               ...
# 3312       2.0   40.0               2            1125               362
# 3313       3.0  206.0               2             365               173
# 3314       3.0   60.0               1            1125               143
# 3315       NaN   68.0               1             365               365
# 3316       1.0   35.0               1            1125               365
#
#       number_of_reviews  reviews_per_month host_is_superhost  \
# 0                    23               1.04                 f
# 1                    63               1.53                 f
# 2                    16               2.54                 t
# 3                    26               1.29                 f
# 4                     1               1.00                 f
# ...                 ...                ...               ...
# 3312                  0               0.00                 f
# 3313                  0               0.00                 t
# 3314                  0               0.00                 f
# 3315                  0               0.00                 f
# 3316                  0               0.00                 f
#
#                                               amenities
# 0                                                    {}
# 1     {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 2     {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 3     {TV,"Wireless Internet",Kitchen,"Free Parking ...
# 4     {TV,Internet,"Wireless Internet",Kitchen,"Free...
# ...                                                 ...
# 3312  ["Iron", "First aid kit", "Shampoo", "Wifi", "...
# 3313  ["Hot water", "Shampoo", "Wifi", "Essentials",...
# 3314  ["Iron", "Lockbox", "Breakfast", "Wifi", "Esse...
# 3315  ["Iron", "Dryer", "Hot water", "Fire extinguis...
# 3316  ["Iron", "Shampoo", "Wifi", "Essentials", "TV"...
#
# [5774 rows x 18 columns]

# %%
combined_df.sort_values(by='accommodates', ascending=False, inplace=True)

# %%
combined_df['bedrooms'].fillna(axis=0, method='bfill', inplace=True)

# %% [markdown]
# # Manually encode amenities

# %%
combined_df.isna().sum()
# Out:
# id                        0
# neighbourhood_cleansed    0
# city                      0
# latitude                  0
# longitude                 0
# property_type             0
# room_type                 0
# accommodates              0
# bathrooms                 0
# bedrooms                  0
# price                     0
# minimum_nights            0
# maximum_nights            0
# availability_365          0
# number_of_reviews         0
# reviews_per_month         0
# host_is_superhost         0
# amenities                 0
# dtype: int64

# %%
combined_df.amenities.tolist()
# Out:
# ['["Iron", "Hot water", "Fire extinguisher", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Wifi", "Stove", "Private entrance", "Smoke alarm", "Oven", "Bed linens", "Essentials", "Hangers", "Heating", "Paid parking off premises", "Lockbox", "Cooking basics", "TV", "Dishes and silverware", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Hot water", "Private living room", "Long term stays allowed", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Ethernet connection", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Bathtub", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Dishes and silverware", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Dryer", "Cooking basics", "Hot water", "Wifi", "TV", "Free parking on premises", "Private living room", "Heating", "Coffee maker", "Washer", "Microwave", "Dishes and silverware", "Private entrance", "Dishwasher", "Refrigerator", "Kitchen", "Bathtub"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Private living room", "Long term stays allowed", "Kitchen", "Ethernet connection", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Host greets you", "Bathtub", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Bed linens", "Cooking basics", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Heating,"Family/Kid Friendly","Suitable for Events",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials}',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Kitchen", "Free street parking", "Wifi", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Coffee maker", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Indoor fireplace", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Shampoo", "Fire extinguisher", "Kitchen", "Wifi", "Private entrance", "Microwave", "First aid kit", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Patio or balcony", "Dryer", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{TV,"Wireless Internet",Heating,"Smoke Detector","Fire Extinguisher",Essentials}',
#  '["Iron", "Hot water", "Shampoo", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Shampoo", "Carbon monoxide alarm", "Kitchen", "Wifi", "Private entrance", "Smoke alarm", "Garden or backyard", "Bed linens", "Essentials", "Hangers", "Heating", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Wifi", "Essentials", "TV", "Private entrance", "Heating", "Carbon monoxide alarm", "Kitchen", "Smoke alarm"]',
#  '["Wifi", "Host greets you", "Stove", "Hair dryer", "Essentials", "Dishes and silverware", "Fire extinguisher", "Free parking on premises", "Hangers", "Garden or backyard", "Refrigerator", "Kitchen", "TV", "Oven", "Microwave", "Cooking basics", "Hot water", "Iron", "Smoke alarm", "Patio or balcony", "Heating"]',
#  '["Iron", "Dryer", "Bed linens", "Cooking basics", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Wifi", "Stove", "Washer", "Free street parking", "Hair dryer", "Dishes and silverware", "Fire extinguisher", "Hangers", "Refrigerator", "Kitchen", "First aid kit", "Oven", "Microwave", "Cooking basics", "Breakfast", "Carbon monoxide alarm", "Iron", "Smoke alarm", "Essentials", "Heating", "Shampoo"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Wifi", "Garden or backyard", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Paid parking off premises", "Freezer", "Hot tub", "Patio or balcony", "Cooking basics", "TV", "Washer", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Hot water", "Wifi", "Essentials", "TV", "Hangers", "Heating", "Washer", "Carbon monoxide alarm", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Carbon monoxide alarm", "Kitchen", "Wifi", "Private entrance", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Wifi", "Essentials", "TV", "Hangers", "Heating", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Long term stays allowed", "Cable TV", "Pack \\u2019n Play/travel crib", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Air conditioning", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Host greets you", "Bathtub", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator"]',
#  '["Iron", "Wifi", "Essentials", "TV", "Hangers", "Heating", "Dishes and silverware", "Carbon monoxide alarm", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Wifi", "Fire extinguisher", "Kitchen", "TV", "Cooking basics", "Carbon monoxide alarm", "Laptop-friendly workspace", "Iron", "Hair dryer", "Smoke alarm", "Dishes and silverware", "Private entrance", "Shampoo", "Essentials", "Bed linens", "Oven", "Heating", "Dishwasher", "Refrigerator", "Microwave"]',
#  '["Iron", "Dryer \\u2013 In building", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Free street parking", "Wifi", "HDTV", "Microwave", "Washer \\u2013\\u00a0In building", "Garden or backyard", "Smoke alarm", "Shower gel", "Bed linens", "Essentials", "Hangers", "Heating", "Body soap", "Free parking on premises", "Lock on bedroom door", "Conditioner", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Lockbox", "Free street parking", "Dryer", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Cable TV", "Carbon monoxide alarm", "Kitchen", "Ethernet connection", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Extra pillows and blankets", "Bed linens", "Essentials", "Hangers", "Heating", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Children\\u2019s books and toys", "Carbon monoxide alarm", "Dishwasher", "Pack \\u2019n Play/travel crib", "Kitchen", "BBQ grill", "Luggage dropoff allowed", "Wifi", "Stove", "Microwave", "Barbecue utensils", "First aid kit", "Garden or backyard", "High chair", "Baking sheet", "Oven", "Smoke alarm", "Record player", "Bed linens", "Extra pillows and blankets", "Shower gel", "Stair gates", "Essentials", "Hangers", "Heating", "Coffee maker", "Body soap", "Children\\u2019s dinnerware", "Host greets you", "Freezer", "Patio or balcony", "Dryer", "Cooking basics", "Breakfast", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Conditioner", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "First aid kit", "Dryer", "Hot water", "Breakfast", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Hangers", "Heating", "Lock on bedroom door", "Washer", "Fire extinguisher", "Carbon monoxide alarm", "Kitchen", "Smoke alarm"]',
#  '{Kitchen,"Free Parking on Premises",Heating,"Suitable for Events",Washer,Dryer,"Smoke Detector"}',
#  '["Iron", "Lockbox", "Cooking basics", "Hot water", "Wifi", "Essentials", "TV", "Private entrance", "Heating", "Dishes and silverware", "Carbon monoxide alarm", "Dishwasher", "Refrigerator", "Paid parking off premises", "Hair dryer", "Kitchen", "Smoke alarm", "Oven"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Bathtub", "Lockbox", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Dishes and silverware", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials}',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Cable TV", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "BBQ grill", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "Barbecue utensils", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Shower gel", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Freezer", "Patio or balcony", "Dryer", "Cooking basics", "Cleaning before checkout", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Hair dryer", "Patio or balcony", "Dishes and silverware", "Bed linens", "Fire extinguisher", "Free parking on premises", "Garden or backyard", "Indoor fireplace", "Cable TV", "Refrigerator", "Kitchen", "TV", "Laptop-friendly workspace", "Bathtub", "Oven", "Dishwasher", "Microwave", "Cooking basics", "Carbon monoxide alarm", "Iron", "BBQ grill", "Smoke alarm", "Essentials", "Heating", "Shampoo"]',
#  '["Iron", "Dryer", "Shampoo", "Wifi", "Essentials", "TV", "Hangers", "Private entrance", "Heating", "Fire extinguisher", "Washer", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Hot Tub","Indoor Fireplace",Heating,"Family/Kid Friendly","Suitable for Events",Washer,"Smoke Detector",Essentials}',
#  '["Wifi", "Lockbox", "Kitchen", "Fire extinguisher", "First aid kit", "Washer", "Hangers", "Carbon monoxide alarm", "Iron", "Hair dryer", "Smoke alarm", "Dishes and silverware", "Paid parking off premises", "Private entrance", "Essentials", "Heating", "Shampoo"]',
#  '["Iron", "Dryer", "Hot water", "Wifi", "TV", "Free parking on premises", "Private living room", "Heating", "Coffee maker", "Washer", "Microwave", "Dishes and silverware", "Private entrance", "Dishwasher", "Refrigerator", "Kitchen", "Bathtub"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Carbon monoxide alarm", "Kitchen", "Free street parking", "BBQ grill", "Luggage dropoff allowed", "Wifi", "Stove", "Microwave", "Crib", "Garden or backyard", "High chair", "Oven", "Smoke alarm", "Shower gel", "Bed linens", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Hot tub", "Bathtub", "Smart lock", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Indoor fireplace", "Carbon monoxide alarm", "Kitchen", "Ethernet connection", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "Crib", "Garden or backyard", "Oven", "High chair", "Smoke alarm", "Bed linens", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Smart lock", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Indoor fireplace", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "Crib", "Garden or backyard", "High chair", "Oven", "Smoke alarm", "Extra pillows and blankets", "Bed linens", "Shower gel", "Essentials", "Hangers", "Heating", "Coffee maker", "Bathtub", "Smart lock", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "First aid kit", "Smoke alarm", "Oven", "Bed linens", "Essentials", "Hangers", "Heating", "Coffee maker", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Host greets you", "Children\\u2019s dinnerware", "Stove", "Washer", "Free street parking", "Babysitter recommendations", "Hair dryer", "Dishes and silverware", "Fire extinguisher", "Free parking on premises", "Hangers", "Dryer", "Children\\u2019s books and toys", "Cable TV", "Refrigerator", "Stair gates", "Shampoo", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Air conditioning", "Oven", "Dishwasher", "Luggage dropoff allowed", "Microwave", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Changing table", "Essentials", "Heating", "Indoor fireplace"]',
#  '["Iron", "Dryer", "Shampoo", "Wifi", "Fire extinguisher", "TV", "Heating", "Washer", "Air conditioning", "First aid kit", "Smoke alarm"]',
#  '["Wifi", "Kitchen", "TV", "Private entrance", "Heating"]',
#  '["Iron", "Dryer", "Hot water", "Wifi", "TV", "Private entrance", "Heating", "Coffee maker", "Washer", "Microwave", "Dishes and silverware", "Dishwasher", "Refrigerator", "Kitchen", "Garden or backyard", "Bathtub"]',
#  '{Kitchen,Heating,"Family/Kid Friendly","Suitable for Events",Washer,Dryer,"Smoke Detector","First Aid Kit","Fire Extinguisher"}',
#  '["Iron", "Hot water", "Shampoo", "Dishwasher", "Kitchen", "Ethernet connection", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "Garden or backyard", "Oven", "Bed linens", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Lockbox", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Fire extinguisher", "Kitchen", "TV", "Free parking on premises", "First aid kit", "Washer", "Dryer", "Hangers", "Carbon monoxide alarm", "Hot water", "Iron", "Hair dryer", "Smoke alarm", "Private entrance", "Essentials", "Air conditioning", "Heating"]',
#  '["Wifi", "Fire extinguisher", "Kitchen", "TV", "Free parking on premises", "First aid kit", "Washer", "Dryer", "Hangers", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hot water", "Iron", "Hair dryer", "Smoke alarm", "Private entrance", "Essentials", "Air conditioning", "Heating"]',
#  '["Iron", "Dryer", "Hot water", "Wifi", "TV", "Free parking on premises", "Private living room", "Heating", "Coffee maker", "Washer", "Microwave", "Dishes and silverware", "Private entrance", "Dishwasher", "Refrigerator", "Kitchen", "Bathtub"]',
#  '["Wifi", "Stove", "Washer", "Hair dryer", "Dishes and silverware", "Keypad", "Fire extinguisher", "Room-darkening shades", "Hangers", "Refrigerator", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Pack \\u2019n Play/travel crib", "Oven", "Dishwasher", "Microwave", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Coffee maker", "Essentials", "Heating", "Shampoo"]',
#  '["Wifi", "Stove", "Washer", "Free street parking", "Babysitter recommendations", "Hair dryer", "Barbecue utensils", "Dishes and silverware", "Patio or balcony", "Bed linens", "Fire extinguisher", "Room-darkening shades", "Garden or backyard", "Children\\u2019s books and toys", "Shower gel", "Refrigerator", "Shampoo", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Smart lock", "Bathtub", "Oven", "Long term stays allowed", "Dishwasher", "Microwave", "Crib", "Cooking basics", "Breakfast", "Carbon monoxide alarm", "Hot water", "Iron", "BBQ grill", "Smoke alarm", "Changing table", "Private entrance", "Essentials", "Heating", "Indoor fireplace"]',
#  '["Iron", "Keypad", "Hot water", "Shampoo", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Essentials", "Hangers", "Heating", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Dryer", "Hot water", "Wifi", "TV", "Free parking on premises", "Private entrance", "Heating", "Coffee maker", "Washer", "Microwave", "Dishes and silverware", "Dishwasher", "Refrigerator", "Kitchen", "Bathtub"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher"}',
#  '["Iron", "Dryer", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Fire extinguisher", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Wifi", "Essentials", "TV", "Hangers", "Heating", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Shampoo", "Fire extinguisher", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Wifi", "Private entrance", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Washer", "Hair dryer", "Dishes and silverware", "Fire extinguisher", "Free parking on premises", "Hangers", "Dryer", "Indoor fireplace", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Breakfast", "Carbon monoxide alarm", "Iron", "Smoke alarm", "Private entrance", "Coffee maker", "Essentials", "Heating", "Shampoo"]',
#  '["Iron", "Dryer", "Bed linens", "Cooking basics", "Shampoo", "Wifi", "Essentials", "TV", "Hangers", "Private entrance", "Heating", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Cable TV", "Kitchen", "Free street parking", "Wifi", "Microwave", "Elevator", "Gym", "First aid kit", "Smoke alarm", "Essentials", "Hangers", "Heating", "Paid parking off premises", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{TV,"Wireless Internet",Kitchen,Heating,"Smoke Detector","Fire Extinguisher",Essentials}',
#  '["Iron", "Patio or balcony", "Hot water", "Wifi", "Essentials", "TV", "Hangers", "Heating", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Dishwasher", "Refrigerator", "Hair dryer", "Kitchen", "Smoke alarm", "Oven"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Indoor fireplace", "Kitchen", "Free street parking", "Wifi", "Private entrance", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Paid parking off premises", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Stove", "Washer", "Hair dryer", "Dishes and silverware", "Bed linens", "Room-darkening shades", "Free parking on premises", "Hangers", "Dryer", "Garden or backyard", "Refrigerator", "High chair", "Kitchen", "TV", "Laptop-friendly workspace", "Bathtub", "Oven", "Dishwasher", "Microwave", "Lockbox", "Crib", "Cooking basics", "Hot water", "Iron", "Smoke alarm", "Paid parking off premises", "Coffee maker", "Essentials", "Heating", "Shampoo"]',
#  '{TV,"Cable TV","Wireless Internet",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,"Hair Dryer",Iron}',
#  '["Iron", "Free street parking", "Dryer", "Bed linens", "Cooking basics", "Hot water", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Long term stays allowed", "Heating", "Hangers", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,"Hair Dryer",Iron}',
#  '["Iron", "Hot water", "Shampoo", "Children\\u2019s books and toys", "Carbon monoxide alarm", "Dishwasher", "Babysitter recommendations", "Pack \\u2019n Play/travel crib", "Kitchen", "Wifi", "Stove", "Private entrance", "Microwave", "Crib", "First aid kit", "Garden or backyard", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Coffee maker", "Bathtub", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Stove", "Washer", "Free street parking", "Hair dryer", "Patio or balcony", "Dishes and silverware", "Bed linens", "Fire extinguisher", "Room-darkening shades", "Free parking on premises", "Extra pillows and blankets", "Hangers", "Dryer", "Garden or backyard", "Refrigerator", "Shampoo", "Kitchen", "Laptop-friendly workspace", "Oven", "Long term stays allowed", "Dishwasher", "Luggage dropoff allowed", "Microwave", "Fireplace guards", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Private entrance", "Coffee maker", "Essentials", "Heating", "Indoor fireplace"]',
#  '{TV,"Cable TV","Wireless Internet",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,"Hair Dryer",Iron}',
#  '["Wifi", "Host greets you", "Children\\u2019s dinnerware", "Stove", "Washer", "Babysitter recommendations", "Hair dryer", "Dishes and silverware", "Fire extinguisher", "Room-darkening shades", "Outlet covers", "Free parking on premises", "Hangers", "Dryer", "Garden or backyard", "Children\\u2019s books and toys", "Refrigerator", "Stair gates", "High chair", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Pack \\u2019n Play/travel crib", "Bathtub", "Oven", "Dishwasher", "Luggage dropoff allowed", "Fireplace guards", "Microwave", "Crib", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Changing table", "Coffee maker", "Essentials", "Window guards", "Baby monitor", "Heating", "Indoor fireplace"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Cable TV", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Host greets you", "Bathtub", "Patio or balcony", "Dryer", "Cooking basics", "Breakfast", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Wifi", "Essentials", "TV", "Hangers", "Heating", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '{TV,"Cable TV","Wireless Internet",Kitchen,Heating,"Family/Kid Friendly","Suitable for Events",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,"24-Hour Check-in",Hangers,"Hair Dryer",Iron}',
#  '["Iron", "Free street parking", "Dryer", "Bed linens", "Cooking basics", "Hot water", "Shampoo", "Wifi", "Essentials", "TV", "Hangers", "Private entrance", "Heating", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Dryer", "Bed linens", "Cooking basics", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Dishes and silverware", "Indoor fireplace", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Shampoo", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Wifi", "Private entrance", "Smoke alarm", "Oven", "Bed linens", "Essentials", "Hangers", "Heating", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Stove", "Ethernet connection", "Washer", "Free street parking", "Babysitter recommendations", "Hair dryer", "Waterfront", "Patio or balcony", "Dishes and silverware", "Bed linens", "Fire extinguisher", "Free parking on premises", "Extra pillows and blankets", "Hangers", "Dryer", "Garden or backyard", "Refrigerator", "Stair gates", "High chair", "Shampoo", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Bathtub", "Oven", "Long term stays allowed", "Dishwasher", "Luggage dropoff allowed", "Microwave", "Lockbox", "Cooking basics", "Carbon monoxide alarm", "Pocket wifi", "Hot water", "Iron", "Smoke alarm", "Private entrance", "Coffee maker", "Essentials", "Heating", "Indoor fireplace"]',
#  '["Iron", "Shampoo", "Fire extinguisher", "Kitchen", "Free street parking", "Wifi", "Private entrance", "Garden or backyard", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Dryer", "Bed linens", "Cooking basics", "Shampoo", "Wifi", "Essentials", "TV", "Hangers", "Private entrance", "Heating", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm", "Oven"]',
#  '["Wifi", "Host greets you", "Stove", "Washer", "Free street parking", "Hair dryer", "Patio or balcony", "Dishes and silverware", "Fire extinguisher", "Hangers", "Garden or backyard", "Children\\u2019s books and toys", "Refrigerator", "Shampoo", "Kitchen", "Cleaning before checkout", "Bathtub", "Oven", "Dishwasher", "Fireplace guards", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "BBQ grill", "Smoke alarm", "Coffee maker", "Essentials", "Heating", "Indoor fireplace"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Lake access", "Children\\u2019s books and toys", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Pack \\u2019n Play/travel crib", "Kitchen", "Ethernet connection", "Free street parking", "BBQ grill", "Wifi", "Stove", "Pocket wifi", "Waterfront", "Microwave", "Changing table", "Crib", "First aid kit", "Garden or backyard", "High chair", "Oven", "Smoke alarm", "Bed linens", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Children\\u2019s dinnerware", "Bathtub", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Dryer", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Hangers", "Heating", "Fire extinguisher", "Washer", "Indoor fireplace", "Carbon monoxide alarm", "Laptop-friendly workspace", "Kitchen", "Smoke alarm"]',
#  '["Wifi", "Lockbox", "Kitchen", "TV", "Fire extinguisher", "First aid kit", "Washer", "Hangers", "Carbon monoxide alarm", "Free street parking", "Hot water", "Iron", "Hair dryer", "Smoke alarm", "Private entrance", "Cable TV", "Essentials", "Shampoo", "Heating", "Indoor fireplace"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Indoor fireplace", "Carbon monoxide alarm", "Kitchen", "Free street parking", "BBQ grill", "Wifi", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Window guards", "Bed linens", "Essentials", "Hangers", "Heating", "Dryer", "Cooking basics", "Cleaning before checkout", "TV", "Washer", "Refrigerator", "Laptop-friendly workspace"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Coffee maker", "Lockbox", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Dryer", "Bed linens", "Cooking basics", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Wifi", "Stove", "Washer", "Free street parking", "Hair dryer", "Patio or balcony", "Dishes and silverware", "Hangers", "Garden or backyard", "Refrigerator", "Kitchen", "TV", "Cleaning before checkout", "Bathtub", "Long term stays allowed", "Oven", "Luggage dropoff allowed", "Microwave", "Cooking basics", "Hot water", "Iron", "Smoke alarm", "Essentials", "Heating"]',
#  '["Wifi", "Hair dryer", "Essentials", "Dishes and silverware", "Bed linens", "Fire extinguisher", "Refrigerator", "Kitchen", "TV", "Laptop-friendly workspace", "Oven", "Dishwasher", "Microwave", "Cooking basics", "Carbon monoxide alarm", "Iron", "Smoke alarm", "Private entrance", "Patio or balcony", "Heating", "Shampoo"]',
#  '["Wifi", "Washer", "Free street parking", "Hair dryer", "Essentials", "Dishes and silverware", "Fire extinguisher", "Free parking on premises", "Hangers", "Dryer", "Refrigerator", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Private entrance", "Patio or balcony", "Heating", "Indoor fireplace"]',
#  '["Iron", "Shampoo", "Wifi", "Essentials", "TV", "Hangers", "Fire extinguisher", "Heating", "Washer", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Carbon monoxide alarm", "Babysitter recommendations", "Kitchen", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Smoke alarm", "Oven", "High chair", "Extra pillows and blankets", "Bed linens", "Essentials", "Hangers", "Heating", "Coffee maker", "Cooking basics", "Cleaning before checkout", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Free street parking", "Dryer", "Cooking basics", "Fire extinguisher", "Wifi", "Essentials", "TV", "Free parking on premises", "Hangers", "Heating", "Washer", "Dishes and silverware", "Carbon monoxide alarm", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Breakfast", "Shampoo", "Wifi", "TV", "Hangers", "Heating"]',
#  '["Wifi", "Essentials", "Hangers", "Washer", "Elevator", "Laptop-friendly workspace"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Iron}',
#  '["Dryer", "Wifi", "Essentials", "TV", "Free parking on premises", "Heating", "Washer", "Carbon monoxide alarm", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Keypad", "Hot water", "Shampoo", "Fire extinguisher", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Private entrance", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Hair dryer"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Pets Allowed",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Cable TV", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Ethernet connection", "Free street parking", "Wifi", "Stove", "Private entrance", "Pocket wifi", "Air conditioning", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Shower gel", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Baking sheet", "Smoke alarm", "Essentials", "Hangers", "Heating", "Bathtub", "Patio or balcony", "Cooking basics", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Keypad", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Carbon monoxide alarm", "Dishwasher", "Pack \\u2019n Play/travel crib", "Kitchen", "Luggage dropoff allowed", "Wifi", "Stove", "HDTV with Netflix, Amazon Prime Video", "Microwave", "First aid kit", "Smoke alarm", "Oven", "Shower gel", "Bed linens", "Essentials", "Hangers", "Heating", "Coffee maker", "Body soap", "Freezer", "Bathtub", "Cooking basics", "Nespresso machine", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Free street parking", "Dryer", "Cooking basics", "Hot water", "Wifi", "Essentials", "Stove", "Free parking on premises", "Heating", "Smoke alarm", "Washer", "Microwave", "Dishes and silverware", "Carbon monoxide alarm", "Refrigerator", "Kitchen", "Garden or backyard", "Oven"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,"Family/Kid Friendly","Suitable for Events",Washer,"Smoke Detector","Carbon Monoxide Detector"}',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,"Family/Kid Friendly",Washer,"Smoke Detector",Essentials}',
#  '["Iron", "Fire extinguisher", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Smoke alarm", "Oven", "Bed linens", "Essentials", "Hangers", "Heating", "Lockbox", "Dryer", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Free street parking", "Hair dryer", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Hangers", "Heating", "Washer", "Microwave", "Dishes and silverware", "Carbon monoxide alarm", "Refrigerator", "Host greets you", "Kitchen", "Smoke alarm"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,"Family/Kid Friendly","Suitable for Events",Washer,"Smoke Detector","Carbon Monoxide Detector",Essentials}',
#  '{TV,Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Free Parking on Premises","Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly","Suitable for Events",Washer,Dryer,"Smoke Detector","First Aid Kit","Fire Extinguisher",Essentials}',
#  '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '["Wifi", "Fire extinguisher", "Kitchen", "TV", "Free parking on premises", "First aid kit", "Washer", "Dryer", "Hangers", "Carbon monoxide alarm", "Laptop-friendly workspace", "Iron", "Hair dryer", "Smoke alarm", "Dishes and silverware", "Private entrance", "Essentials", "Air conditioning", "Heating"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector",Essentials}',
#  '{Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector",Essentials}',
#  '["Iron", "Hot water", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Garden or backyard", "Oven", "Smoke alarm", "Essentials", "Hangers", "Heating", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Stove", "Washer", "Free street parking", "Hair dryer", "Dishes and silverware", "Bed linens", "Fire extinguisher", "Free parking on premises", "Hangers", "Garden or backyard", "Refrigerator", "Kitchen", "TV", "First aid kit", "Air conditioning", "Oven", "Microwave", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Private entrance", "Essentials", "Heating"]',
#  '["Shampoo", "Wifi", "Essentials", "Fire extinguisher", "Heating", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Extra pillows and blankets", "Bed linens", "Essentials", "Hangers", "Heating", "Host greets you", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Dryer", "Wifi", "Free parking on premises", "Heating", "Washer", "Kitchen"]',
#  '["Iron", "Keypad", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Indoor fireplace", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Shower gel", "Essentials", "Hangers", "Heating", "Coffee maker", "Bathtub", "Cooking basics", "Breakfast", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Long term stays allowed", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Microwave", "Smoke alarm", "Oven", "Essentials", "Heating", "Coffee maker", "Cooking basics", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Breakfast,"Hot Tub","Indoor Fireplace",Heating,"Family/Kid Friendly",Washer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,Iron,"Laptop Friendly Workspace"}',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Children\\u2019s books and toys", "Carbon monoxide alarm", "Dishwasher", "Pack \\u2019n Play/travel crib", "Kitchen", "Ethernet connection", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "High chair", "Smoke alarm", "Shower gel", "Extra pillows and blankets", "Bed linens", "Room-darkening shades", "Essentials", "Hangers", "Heating", "Coffee maker", "Children\\u2019s dinnerware", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "Cleaning before checkout", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,"Suitable for Events",Washer,Dryer}',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Children\\u2019s books and toys", "Cable TV", "Carbon monoxide alarm", "Dishwasher", "Pack \\u2019n Play/travel crib", "Kitchen", "Ethernet connection", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "High chair", "Oven", "Smoke alarm", "Bed linens", "Shower gel", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Children\\u2019s dinnerware", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "Breakfast", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Children\\u2019s books and toys", "Indoor fireplace", "Carbon monoxide alarm", "Pack \\u2019n Play/travel crib", "Kitchen", "Luggage dropoff allowed", "Wifi", "Air conditioning", "Microwave", "Crib", "First aid kit", "Smoke alarm", "High chair", "Essentials", "Hangers", "Heating", "Coffee maker", "Lockbox", "Dryer", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Essentials", "Hangers", "Heating", "Hot tub", "Lockbox", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Private living room", "Long term stays allowed", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Bathtub", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Free street parking", "First aid kit", "Dryer", "Breakfast", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Lock on bedroom door", "Fire extinguisher", "Carbon monoxide alarm", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Long term stays allowed", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Shower gel", "Bed linens", "Essentials", "Hangers", "Heating", "Coffee maker", "Lockbox", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Wifi", "Fire extinguisher", "Kitchen", "First aid kit", "Washer", "Dryer", "Hangers", "Carbon monoxide alarm", "Laptop-friendly workspace", "Iron", "Hair dryer", "Smoke alarm", "Private entrance", "Essentials", "Heating"]',
#  '["Wifi", "Stove", "Washer", "Free street parking", "Hair dryer", "Dishes and silverware", "Bed linens", "Hangers", "Garden or backyard", "Children\\u2019s books and toys", "Refrigerator", "High chair", "Shampoo", "Kitchen", "TV", "First aid kit", "Laptop-friendly workspace", "Oven", "Dishwasher", "Microwave", "Crib", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Private entrance", "Essentials", "Heating", "Indoor fireplace"]',
#  '{TV,"Wireless Internet",Kitchen,Heating,"Smoke Detector","Fire Extinguisher",Essentials,"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Cable TV", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Smoke alarm", "Oven", "Extra pillows and blankets", "Bed linens", "Essentials", "Hangers", "Heating", "Coffee maker", "Paid parking off premises", "Lockbox", "Dryer", "Cooking basics", "Cleaning before checkout", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Children\\u2019s books and toys", "Cable TV", "Carbon monoxide alarm", "Pack \\u2019n Play/travel crib", "Kitchen", "Ethernet connection", "Free street parking", "Wifi", "Private entrance", "Microwave", "Crib", "First aid kit", "Garden or backyard", "High chair", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Bathtub", "TV", "Free parking on premises", "Building staff", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Bread maker", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Cable TV", "Indoor fireplace", "Carbon monoxide alarm", "Kitchen", "Ethernet connection", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Air conditioning", "Microwave", "First aid kit", "Smoke alarm", "Oven", "Baking sheet", "Bed linens", "Shower gel", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Coffee maker", "Cooking basics", "Breakfast", "Cleaning before checkout", "TV", "Free parking on premises", "Lock on bedroom door", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Shampoo", "Fire extinguisher", "Indoor fireplace", "Carbon monoxide alarm", "Kitchen", "Wifi", "Private entrance", "Smoke alarm", "Essentials", "Hangers", "Heating", "Hot tub", "Lockbox", "Dryer", "Breakfast", "TV", "Free parking on premises", "Washer", "Laptop-friendly workspace", "Hair dryer"]',
# ...
#  '["Iron", "Shampoo", "Carbon monoxide alarm", "Kitchen", "Wifi", "Microwave", "Elevator", "First aid kit", "Smoke alarm", "Oven", "Extra pillows and blankets", "Bed linens", "Essentials", "Hangers", "Heating", "Cooking basics", "TV", "Free parking on premises", "Washer", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Dryer", "Fire extinguisher", "Wifi", "Essentials", "TV", "Hangers", "Private entrance", "Heating", "Carbon monoxide alarm", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free Parking on Premises","Pets Allowed",Breakfast,"Pets live on this property",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit",Essentials}',
#  '{TV,"Cable TV",Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials}',
#  '["Iron", "Lockbox", "Hot water", "Shampoo", "Wifi", "Essentials", "TV", "Hangers", "Private entrance", "Heating", "Washer", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Bedroom comforts", "Bathroom essentials", "Hair dryer", "Fire extinguisher", "Children\\u2019s dinnerware", "Wifi", "TV", "Self check-in", "Heating", "Coffee maker", "Washer", "Carbon monoxide alarm", "Full kitchen", "Dishwasher", "Paid parking off premises", "Pack \\u2019n Play/travel crib", "Crib", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Kitchen", "Free street parking", "Wifi", "Private entrance", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Bathtub", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Fire extinguisher", "Children\\u2019s books and toys", "Carbon monoxide alarm", "Dishwasher", "Pack \\u2019n Play/travel crib", "Bathroom essentials", "Wifi", "Full kitchen", "Crib", "Smoke alarm", "Window guards", "Bedroom comforts", "Room-darkening shades", "Self check-in", "Heating", "Coffee maker", "Game console", "Children\\u2019s dinnerware", "Paid parking off premises", "Bathtub", "TV", "Washer", "Hair dryer"]',
#  '["Iron", "Free street parking", "Hot water", "Wifi", "Essentials", "TV", "Free parking on premises", "Hangers", "Heating", "Coffee maker", "Washer", "Dishes and silverware", "Laptop-friendly workspace", "Hair dryer", "Kitchen"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '{TV,Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector",Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Children\\u2019s books and toys", "Cable TV", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Private entrance", "Microwave", "Outlet covers", "Crib", "First aid kit", "Garden or backyard", "Oven", "High chair", "Smoke alarm", "Shower gel", "Stair gates", "Essentials", "Hangers", "Heating", "Coffee maker", "Freezer", "Lockbox", "Cooking basics", "Breakfast", "TV", "Free parking on premises", "Washer", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Hot water", "Fire extinguisher", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Garden or backyard", "Oven", "Smoke alarm", "Essentials", "Hangers", "Heating", "Host greets you", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Lake access", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Air conditioning", "Microwave", "Elevator", "Gym", "Smoke alarm", "Oven", "High chair", "Essentials", "Hangers", "Heating", "Paid parking off premises", "Host greets you", "Patio or balcony", "Dryer", "Cooking basics", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Shampoo", "Carbon monoxide alarm", "Kitchen", "Microwave", "Elevator", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Coffee maker", "Patio or balcony", "Cooking basics", "TV", "Building staff", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Bread maker", "Hot water", "Shampoo", "Long term stays allowed", "Children\\u2019s books and toys", "Kitchen", "Free street parking", "Wifi", "Single level home", "Microwave", "Crib", "Garden or backyard", "Oven", "Smoke alarm", "Essentials", "Hangers", "Heating", "Bathtub", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Refrigerator", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Carbon monoxide alarm", "Kitchen", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Shower gel", "Extra pillows and blankets", "Essentials", "Hangers", "Heating", "Lockbox", "Patio or balcony", "Cooking basics", "Cleaning before checkout", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{TV,Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector",Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '{TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,Breakfast,"Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '["Iron", "Lockbox", "Breakfast", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Shampoo", "Fire extinguisher", "Essentials", "TV", "Free parking on premises", "Heating", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Private entrance", "Garden or backyard", "Oven", "Smoke alarm", "Essentials", "Hangers", "Heating", "Bathtub", "Lockbox", "Patio or balcony", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Wifi", "Stove", "Private entrance", "Microwave", "Crib", "First aid kit", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Coffee maker", "Lockbox", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Breakfast", "Fire extinguisher", "Wifi", "Essentials", "Private living room", "Private entrance", "Lock on bedroom door", "Air conditioning", "Kitchen", "Smoke alarm"]',
#  '["Fire extinguisher", "Wifi", "Essentials", "TV", "Hangers", "Private entrance", "Heating", "Microwave", "Refrigerator", "Laptop-friendly workspace", "Kitchen", "Smoke alarm", "Oven"]',
#  '["Iron", "Bed linens", "Cooking basics", "Hot water", "Shampoo", "Wifi", "Essentials", "Stove", "Heating", "Washer", "Microwave", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm", "Oven"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Carbon monoxide alarm", "Pack \\u2019n Play/travel crib", "Kitchen", "Free street parking", "Luggage dropoff allowed", "Wifi", "Stove", "Microwave", "First aid kit", "Smoke alarm", "Oven", "Baby bath", "High chair", "Extra pillows and blankets", "Bed linens", "Shower gel", "Essentials", "Hangers", "Heating", "Bathtub", "Dryer", "Cooking basics", "Cleaning before checkout", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{TV,Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector",Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '{TV,"Wireless Internet","Wheelchair Accessible",Kitchen,"Free Parking on Premises","Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials}',
#  '["Iron", "Shampoo", "Wifi", "Essentials", "TV", "Hangers", "Heating", "Washer", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Smart lock", "Fire extinguisher", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Carbon monoxide alarm", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Breakfast", "Hair dryer", "Wifi", "Essentials", "Free parking on premises", "Hangers", "Heating", "Coffee maker", "Washer", "Lock on bedroom door", "Carbon monoxide alarm", "Laptop-friendly workspace", "Host greets you", "Kitchen", "Smoke alarm"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '["Iron", "Hot water", "Shampoo", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Free street parking", "Wifi", "Stove", "Microwave", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Coffee maker", "Lockbox", "Cooking basics", "Breakfast", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Long term stays allowed", "Carbon monoxide alarm", "Kitchen", "Ethernet connection", "Free street parking", "BBQ grill", "Wifi", "Stove", "Private entrance", "Microwave", "Garden or backyard", "Oven", "Smoke alarm", "Bed linens", "Essentials", "Hangers", "Heating", "Bathtub", "Smart lock", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Carbon monoxide alarm", "Dishwasher", "Kitchen", "Wifi", "Stove", "Private entrance", "Microwave", "First aid kit", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Lockbox", "Dryer", "Cooking basics", "TV", "Free parking on premises", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '["Iron", "Hot water", "Shampoo", "Carbon monoxide alarm", "Kitchen", "Wifi", "Stove", "Microwave", "Elevator", "Smoke alarm", "Oven", "Essentials", "Hangers", "Heating", "Patio or balcony", "TV", "Building staff", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{TV,"Cable TV",Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Pets Allowed","Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '{TV,Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Free Parking on Premises","Pets Allowed",Breakfast,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector",Essentials,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}',
#  '["Iron", "Hot water", "Fire extinguisher", "Long term stays allowed", "Children\\u2019s books and toys", "Indoor fireplace", "Carbon monoxide alarm", "Dishwasher", "Babysitter recommendations", "Kitchen", "Luggage dropoff allowed", "Wifi", "Stove", "Private entrance", "Microwave", "Crib", "First aid kit", "Garden or backyard", "Oven", "High chair", "Smoke alarm", "Bed linens", "Extra pillows and blankets", "Stair gates", "Essentials", "Hangers", "Heating", "Coffee maker", "Children\\u2019s dinnerware", "Fireplace guards", "Patio or balcony", "Dryer", "Cooking basics", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace"]',
#  '{TV,"Cable TV",Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials}',
#  '["Iron", "Dryer", "Shampoo", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "First aid kit", "Dryer", "Breakfast", "Hair dryer", "Wifi", "Essentials", "TV", "Free parking on premises", "Shampoo", "Heating", "Hangers", "Washer", "Cable TV", "Elevator", "Laptop-friendly workspace", "Host greets you", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Dryer", "Wifi", "Essentials", "TV", "Free parking on premises", "Private entrance", "Heating", "Hangers", "Washer", "Carbon monoxide alarm", "Laptop-friendly workspace", "Hair dryer", "Kitchen", "Smoke alarm"]',
#  '["Iron", "Hot water", "Shampoo", "Fire extinguisher", "Long term stays allowed", "Paid parking on premises", "Carbon monoxide alarm", "Pack \\u2019n Play/travel crib", "Kitchen", "Luggage dropoff allowed", "Wifi", "Microwave", "Elevator", "Gym", "Smoke alarm", "Essentials", "Hangers", "Heating", "Lockbox", "Dryer", "TV", "Washer", "Dishes and silverware", "Refrigerator", "Laptop-friendly workspace", "Hair dryer"]',
#  '{TV,Internet,"Wireless Internet",Kitchen,"Elevator in Building","Indoor Fireplace","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,"Smoke Detector","First Aid Kit","Fire Extinguisher",Essentials,Shampoo,Hangers,"Hair Dryer",Iron}',
#  '["Wifi", "Children\\u2019s dinnerware", "Stove", "Washer", "Free street parking", "Babysitter recommendations", "Hair dryer", "Patio or balcony", "Dishes and silverware", "Room-darkening shades", "Hangers", "Garden or backyard", "Children\\u2019s books and toys", "Cable TV", "Refrigerator", "Shampoo", "Kitchen", "TV", "Laptop-friendly workspace", "Oven", "Dishwasher", "Microwave", "Lockbox", "Cooking basics", "Carbon monoxide alarm", "Hot water", "Iron", "Smoke alarm", "Coffee maker", "Essentials", "Heating", "Indoor fireplace"]',
#  ...]

# %%
#make blank columns for selected amenities
combined_df['has_wifi']=np.nan
combined_df['has_kitchen']=np.nan
combined_df['has_parking']=np.nan
combined_df['has_tv']=np.nan
combined_df['has_washer']=np.nan
combined_df['has_garden']=np.nan
combined_df['has_balcony']=np.nan

# %%
#Use loc and Regex to manually OHE
combined_df.loc[combined_df['amenities'].str.contains("|".join('Wifi')), 'has_wifi']=1
combined_df.loc[combined_df['amenities'].str.contains("|".join('kitchen')), 'has_kitchen']=1
combined_df.loc[combined_df['amenities'].str.contains("|".join('parking')), 'has_parking']=1
combined_df.loc[combined_df['amenities'].str.contains("|".join('tv')), 'has_tv']=1
combined_df.loc[combined_df['amenities'].str.contains("|".join('wash')), 'has_washer']=1
combined_df.loc[combined_df['amenities'].str.contains("|".join('garden')), 'has_garden']=1
combined_df.loc[combined_df['amenities'].str.contains("|".join(['patio','balcony'])), 'has_balcony']=1

# %%
#fill in the rest with 0
combined_df.fillna(value=0,inplace=True)

# %%
combined_df.isna().sum()
# Out:
# id                        0
# neighbourhood_cleansed    0
# city                      0
# latitude                  0
# longitude                 0
# property_type             0
# room_type                 0
# accommodates              0
# bathrooms                 0
# bedrooms                  0
# price                     0
# minimum_nights            0
# maximum_nights            0
# availability_365          0
# number_of_reviews         0
# reviews_per_month         0
# host_is_superhost         0
# amenities                 0
# has_wifi                  0
# has_kitchen               0
# has_parking               0
# has_tv                    0
# has_washer                0
# has_garden                0
# has_balcony               0
# dtype: int64

# %% [markdown]
# # Add supplmentary data

# %% [markdown]
# ## Connect data to wards so we can then combine to additional data

# %%
combined_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Ancoats and Clayton', 'Chorlton', 'Cheetham', 'Moss Side',
#        'Withington', 'Didsbury West', 'Old Moat', 'City Centre',
#        'Fallowfield', 'Brislington East', 'Eastville', 'Whalley Range',
#        'Ashley', 'Tameside  ', 'Rochdale  ', 'Ardwick', 'Salford  ',
#        'Clifton Down', 'Central', 'Henbury & Brentry', 'Burnage',
#        'Hotwells & Harbourside', 'Redland', 'Northenden', 'Rusholme',
#        'Clifton', 'Wigan  ', 'Cotham', 'Avonmouth & Lawrence Weston',
#        'Harpurhey', 'Windmill Hill', 'Lawrence Hill', 'Bolton  ',
#        'Levenshulme', 'Bradford', 'Sharston', 'Worlsey',
#        'Miles Platting and Newton Heath', 'Southville',
#        'Bishopston & Ashley Down', 'Longsight', 'Stoke Bishop', 'Hulme',
#        'Stockport  ', 'Hillfields', 'Bury  ', 'Didsbury East',
#        'Trafford  ', 'St George Troopers Hill', 'Baguley', 'Gorton South',
#        'Oldham  ', 'Easton', 'Higher Blackley', 'Horfield',
#        'Bishopsworth', 'Brislington West', 'St George Central', 'Knowle',
#        'St George West', 'Gorton North', 'Brooklands',
#        'Hartcliffe & Withywood', 'Bedminster', 'Chorlton Park', 'Moston',
#        'Crumpsall', 'Southmead', 'Westbury-on-Trym & Henleaze',
#        'Frome Vale', 'Stockwood', 'Lockleaze',
#        'Hengrove & Whitchurch Park', 'Filwood', 'Charlestown',
#        'Woodhouse Park'], dtype=object)

# %%
#connect wards
wards=pd.read_csv("data//airbnb//supp//Ward_to_Registration_District_to_Local_Authority_District_(December_2019)_Lookup_in_England_and_Wales.csv")

# %%
wards
# Out:
#        FID     WD19CD          WD19NM   REGD19CD                   REGD19NM  \
# 0        1  E05000650   Astley Bridge  E28000001                     Bolton
# 1        2  E05000651        Bradshaw  E28000001                     Bolton
# 2        3  E05000652      Breightmet  E28000001                     Bolton
# 3        4  E05000653   Bromley Cross  E28000001                     Bolton
# 4        5  E05000654        Crompton  E28000001                     Bolton
# ...    ...        ...             ...        ...                        ...
# 8066  8067  W05000175          Ruthin  W20000041  Denbighshire/Sir Ddinbych
# 8067  8068  W05000176  St. Asaph East  W20000041  Denbighshire/Sir Ddinbych
# 8068  8069  W05000177  St. Asaph West  W20000041  Denbighshire/Sir Ddinbych
# 8069  8070  W05000178        Trefnant  W20000041  Denbighshire/Sir Ddinbych
# 8070  8071  W05000179    Tremeirchion  W20000041  Denbighshire/Sir Ddinbych
#
#         LAD19CD       LAD19NM
# 0     E08000001        Bolton
# 1     E08000001        Bolton
# 2     E08000001        Bolton
# 3     E08000001        Bolton
# 4     E08000001        Bolton
# ...         ...           ...
# 8066  W06000004  Denbighshire
# 8067  W06000004  Denbighshire
# 8068  W06000004  Denbighshire
# 8069  W06000004  Denbighshire
# 8070  W06000004  Denbighshire
#
# [8071 rows x 7 columns]

# %%
searchfor=['Manchester', 'Bristol','Trafford','Rochdale','Salford', 'Bolton']
wards_filtered=wards[wards['REGD19NM'].str.contains("|".join(searchfor))]

# %%
wards_filtered
# Out:
#        FID     WD19CD                         WD19NM   REGD19CD REGD19NM  \
# 0        1  E05000650                  Astley Bridge  E28000001   Bolton
# 1        2  E05000651                       Bradshaw  E28000001   Bolton
# 2        3  E05000652                     Breightmet  E28000001   Bolton
# 3        4  E05000653                  Bromley Cross  E28000001   Bolton
# 4        5  E05000654                       Crompton  E28000001   Bolton
# ...    ...        ...                            ...        ...      ...
# 1326  1327  E05010914                     Southville  E28000074  Bristol
# 1327  1328  E05010915                      Stockwood  E28000074  Bristol
# 1328  1329  E05010916                   Stoke Bishop  E28000074  Bristol
# 1329  1330  E05010917  Westbury-on-Trym and Henleaze  E28000074  Bristol
# 1330  1331  E05010918                  Windmill Hill  E28000074  Bristol
#
#         LAD19CD           LAD19NM
# 0     E08000001            Bolton
# 1     E08000001            Bolton
# 2     E08000001            Bolton
# 3     E08000001            Bolton
# 4     E08000001            Bolton
# ...         ...               ...
# 1326  E06000023  Bristol, City of
# 1327  E06000023  Bristol, City of
# 1328  E06000023  Bristol, City of
# 1329  E06000023  Bristol, City of
# 1330  E06000023  Bristol, City of
#
# [147 rows x 7 columns]

# %%
combined_df_wards=combined_df.rename(columns={'neighbourhood_cleansed':'WD19NM'})

# %%
#Anocoats and clayton is now anocats and beswick lets replace

combined_df_wards.replace({'Ancoats and Clayton': 'Ancoats & Beswick'},inplace=True)

# %%
airbnb_wards=combined_df_wards.merge(wards_filtered,on='WD19NM', how='left')

# %%
airbnb_wards
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 5785  45009362             Ashley     Bristol  51.47023   -2.57722
# 5786  42525736           Rusholme  Manchester  53.45374   -2.21489
# 5787  28094403             Knowle     Bristol  51.43610   -2.57409
# 5788    390781   Brislington West     Bristol  51.44429   -2.55777
# 5789  31614043           Old Moat  Manchester  53.43804   -2.23831
#
#                   property_type        room_type  accommodates bathrooms  \
# 0              Entire apartment  Entire home/apt            16         3
# 1         Private room in house     Private room            16         3
# 2              Entire apartment  Entire home/apt            16         3
# 3     Private room in apartment     Private room            16         3
# 4         Private room in house     Private room            16         2
# ...                         ...              ...           ...       ...
# 5785  Private room in townhouse     Private room             1         1
# 5786           Entire apartment  Entire home/apt             1         1
# 5787      Private room in house     Private room             1         1
# 5788      Private room in house     Private room             1         1
# 5789      Private room in house     Private room             1         1
#
#       bedrooms  ...  has_tv  has_washer  has_garden  has_balcony     FID  \
# 0          4.0  ...     1.0         1.0         1.0          0.0    38.0
# 1          6.0  ...     1.0         1.0         1.0          0.0    45.0
# 2          3.0  ...     1.0         1.0         1.0          0.0    38.0
# 3          6.0  ...     1.0         1.0         1.0          0.0    44.0
# 4          4.0  ...     1.0         1.0         1.0          0.0   110.0
# ...        ...  ...     ...         ...         ...          ...     ...
# 5785       1.0  ...     1.0         1.0         1.0          0.0  1298.0
# 5786       1.0  ...     1.0         1.0         1.0          0.0   115.0
# 5787       1.0  ...     1.0         1.0         1.0          0.0  1319.0
# 5788       1.0  ...     1.0         1.0         1.0          0.0  1304.0
# 5789       2.0  ...     1.0         1.0         1.0          0.0   113.0
#
#          WD19CD   REGD19CD    REGD19NM    LAD19CD           LAD19NM
# 0     E05011350  E28000003  Manchester  E08000003        Manchester
# 1     E05011357  E28000003  Manchester  E08000003        Manchester
# 2     E05011350  E28000003  Manchester  E08000003        Manchester
# 3     E05011356  E28000003  Manchester  E08000003        Manchester
# 4     E05011372  E28000003  Manchester  E08000003        Manchester
# ...         ...        ...         ...        ...               ...
# 5785  E05010885  E28000074     Bristol  E06000023  Bristol, City of
# 5786  E05011377  E28000003  Manchester  E08000003        Manchester
# 5787  E05010906  E28000074     Bristol  E06000023  Bristol, City of
# 5788  E05010891  E28000074     Bristol  E06000023  Bristol, City of
# 5789  E05011375  E28000003  Manchester  E08000003        Manchester
#
# [5790 rows x 31 columns]

# %%
airbnb_wards.dropna(inplace=True)

# %%
airbnb_wards
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 5785  45009362             Ashley     Bristol  51.47023   -2.57722
# 5786  42525736           Rusholme  Manchester  53.45374   -2.21489
# 5787  28094403             Knowle     Bristol  51.43610   -2.57409
# 5788    390781   Brislington West     Bristol  51.44429   -2.55777
# 5789  31614043           Old Moat  Manchester  53.43804   -2.23831
#
#                   property_type        room_type  accommodates bathrooms  \
# 0              Entire apartment  Entire home/apt            16         3
# 1         Private room in house     Private room            16         3
# 2              Entire apartment  Entire home/apt            16         3
# 3     Private room in apartment     Private room            16         3
# 4         Private room in house     Private room            16         2
# ...                         ...              ...           ...       ...
# 5785  Private room in townhouse     Private room             1         1
# 5786           Entire apartment  Entire home/apt             1         1
# 5787      Private room in house     Private room             1         1
# 5788      Private room in house     Private room             1         1
# 5789      Private room in house     Private room             1         1
#
#       bedrooms  ...  has_tv  has_washer  has_garden  has_balcony     FID  \
# 0          4.0  ...     1.0         1.0         1.0          0.0    38.0
# 1          6.0  ...     1.0         1.0         1.0          0.0    45.0
# 2          3.0  ...     1.0         1.0         1.0          0.0    38.0
# 3          6.0  ...     1.0         1.0         1.0          0.0    44.0
# 4          4.0  ...     1.0         1.0         1.0          0.0   110.0
# ...        ...  ...     ...         ...         ...          ...     ...
# 5785       1.0  ...     1.0         1.0         1.0          0.0  1298.0
# 5786       1.0  ...     1.0         1.0         1.0          0.0   115.0
# 5787       1.0  ...     1.0         1.0         1.0          0.0  1319.0
# 5788       1.0  ...     1.0         1.0         1.0          0.0  1304.0
# 5789       2.0  ...     1.0         1.0         1.0          0.0   113.0
#
#          WD19CD   REGD19CD    REGD19NM    LAD19CD           LAD19NM
# 0     E05011350  E28000003  Manchester  E08000003        Manchester
# 1     E05011357  E28000003  Manchester  E08000003        Manchester
# 2     E05011350  E28000003  Manchester  E08000003        Manchester
# 3     E05011356  E28000003  Manchester  E08000003        Manchester
# 4     E05011372  E28000003  Manchester  E08000003        Manchester
# ...         ...        ...         ...        ...               ...
# 5785  E05010885  E28000074     Bristol  E06000023  Bristol, City of
# 5786  E05011377  E28000003  Manchester  E08000003        Manchester
# 5787  E05010906  E28000074     Bristol  E06000023  Bristol, City of
# 5788  E05010891  E28000074     Bristol  E06000023  Bristol, City of
# 5789  E05011375  E28000003  Manchester  E08000003        Manchester
#
# [3246 rows x 31 columns]

# %%
airbnb_wards
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 5785  45009362             Ashley     Bristol  51.47023   -2.57722
# 5786  42525736           Rusholme  Manchester  53.45374   -2.21489
# 5787  28094403             Knowle     Bristol  51.43610   -2.57409
# 5788    390781   Brislington West     Bristol  51.44429   -2.55777
# 5789  31614043           Old Moat  Manchester  53.43804   -2.23831
#
#                   property_type        room_type  accommodates bathrooms  \
# 0              Entire apartment  Entire home/apt            16         3
# 1         Private room in house     Private room            16         3
# 2              Entire apartment  Entire home/apt            16         3
# 3     Private room in apartment     Private room            16         3
# 4         Private room in house     Private room            16         2
# ...                         ...              ...           ...       ...
# 5785  Private room in townhouse     Private room             1         1
# 5786           Entire apartment  Entire home/apt             1         1
# 5787      Private room in house     Private room             1         1
# 5788      Private room in house     Private room             1         1
# 5789      Private room in house     Private room             1         1
#
#       bedrooms  ...  has_tv  has_washer  has_garden  has_balcony     FID  \
# 0          4.0  ...     1.0         1.0         1.0          0.0    38.0
# 1          6.0  ...     1.0         1.0         1.0          0.0    45.0
# 2          3.0  ...     1.0         1.0         1.0          0.0    38.0
# 3          6.0  ...     1.0         1.0         1.0          0.0    44.0
# 4          4.0  ...     1.0         1.0         1.0          0.0   110.0
# ...        ...  ...     ...         ...         ...          ...     ...
# 5785       1.0  ...     1.0         1.0         1.0          0.0  1298.0
# 5786       1.0  ...     1.0         1.0         1.0          0.0   115.0
# 5787       1.0  ...     1.0         1.0         1.0          0.0  1319.0
# 5788       1.0  ...     1.0         1.0         1.0          0.0  1304.0
# 5789       2.0  ...     1.0         1.0         1.0          0.0   113.0
#
#          WD19CD   REGD19CD    REGD19NM    LAD19CD           LAD19NM
# 0     E05011350  E28000003  Manchester  E08000003        Manchester
# 1     E05011357  E28000003  Manchester  E08000003        Manchester
# 2     E05011350  E28000003  Manchester  E08000003        Manchester
# 3     E05011356  E28000003  Manchester  E08000003        Manchester
# 4     E05011372  E28000003  Manchester  E08000003        Manchester
# ...         ...        ...         ...        ...               ...
# 5785  E05010885  E28000074     Bristol  E06000023  Bristol, City of
# 5786  E05011377  E28000003  Manchester  E08000003        Manchester
# 5787  E05010906  E28000074     Bristol  E06000023  Bristol, City of
# 5788  E05010891  E28000074     Bristol  E06000023  Bristol, City of
# 5789  E05011375  E28000003  Manchester  E08000003        Manchester
#
# [3246 rows x 31 columns]

# %%
#just making sure I've got the right regions
airbnb_wards.REGD19NM.unique()
# Out:
# array(['Manchester', 'Bristol', 'Trafford'], dtype=object)

# %%
searchfor=['Manchester', 'Bristol','Trafford',]

airbnb_cleaned=airbnb_wards[airbnb_wards['REGD19NM'].str.contains("|".join(searchfor))]

# %%
airbnb_cleaned
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 5785  45009362             Ashley     Bristol  51.47023   -2.57722
# 5786  42525736           Rusholme  Manchester  53.45374   -2.21489
# 5787  28094403             Knowle     Bristol  51.43610   -2.57409
# 5788    390781   Brislington West     Bristol  51.44429   -2.55777
# 5789  31614043           Old Moat  Manchester  53.43804   -2.23831
#
#                   property_type        room_type  accommodates bathrooms  \
# 0              Entire apartment  Entire home/apt            16         3
# 1         Private room in house     Private room            16         3
# 2              Entire apartment  Entire home/apt            16         3
# 3     Private room in apartment     Private room            16         3
# 4         Private room in house     Private room            16         2
# ...                         ...              ...           ...       ...
# 5785  Private room in townhouse     Private room             1         1
# 5786           Entire apartment  Entire home/apt             1         1
# 5787      Private room in house     Private room             1         1
# 5788      Private room in house     Private room             1         1
# 5789      Private room in house     Private room             1         1
#
#       bedrooms  ...  has_tv  has_washer  has_garden  has_balcony     FID  \
# 0          4.0  ...     1.0         1.0         1.0          0.0    38.0
# 1          6.0  ...     1.0         1.0         1.0          0.0    45.0
# 2          3.0  ...     1.0         1.0         1.0          0.0    38.0
# 3          6.0  ...     1.0         1.0         1.0          0.0    44.0
# 4          4.0  ...     1.0         1.0         1.0          0.0   110.0
# ...        ...  ...     ...         ...         ...          ...     ...
# 5785       1.0  ...     1.0         1.0         1.0          0.0  1298.0
# 5786       1.0  ...     1.0         1.0         1.0          0.0   115.0
# 5787       1.0  ...     1.0         1.0         1.0          0.0  1319.0
# 5788       1.0  ...     1.0         1.0         1.0          0.0  1304.0
# 5789       2.0  ...     1.0         1.0         1.0          0.0   113.0
#
#          WD19CD   REGD19CD    REGD19NM    LAD19CD           LAD19NM
# 0     E05011350  E28000003  Manchester  E08000003        Manchester
# 1     E05011357  E28000003  Manchester  E08000003        Manchester
# 2     E05011350  E28000003  Manchester  E08000003        Manchester
# 3     E05011356  E28000003  Manchester  E08000003        Manchester
# 4     E05011372  E28000003  Manchester  E08000003        Manchester
# ...         ...        ...         ...        ...               ...
# 5785  E05010885  E28000074     Bristol  E06000023  Bristol, City of
# 5786  E05011377  E28000003  Manchester  E08000003        Manchester
# 5787  E05010906  E28000074     Bristol  E06000023  Bristol, City of
# 5788  E05010891  E28000074     Bristol  E06000023  Bristol, City of
# 5789  E05011375  E28000003  Manchester  E08000003        Manchester
#
# [3246 rows x 31 columns]

# %% [markdown]
# ## Lost more data than expected, some data was not in manchester,bristol or greater manchester.Greater Manchester was removed in some placedue to missing/incorrect data (Greater manchester data is not at ward level instead at region level, unlike the bristol and manchester data)

# %% [markdown]
# # Adding index of multiple deprivation data

# %%
combined_df.neighbourhood_cleansed.unique()
# Out:
# array(['Ancoats and Clayton', 'Chorlton', 'Cheetham', 'Moss Side',
#        'Withington', 'Didsbury West', 'Old Moat', 'City Centre',
#        'Fallowfield', 'Brislington East', 'Eastville', 'Whalley Range',
#        'Ashley', 'Tameside  ', 'Rochdale  ', 'Ardwick', 'Salford  ',
#        'Clifton Down', 'Central', 'Henbury & Brentry', 'Burnage',
#        'Hotwells & Harbourside', 'Redland', 'Northenden', 'Rusholme',
#        'Clifton', 'Wigan  ', 'Cotham', 'Avonmouth & Lawrence Weston',
#        'Harpurhey', 'Windmill Hill', 'Lawrence Hill', 'Bolton  ',
#        'Levenshulme', 'Bradford', 'Sharston', 'Worlsey',
#        'Miles Platting and Newton Heath', 'Southville',
#        'Bishopston & Ashley Down', 'Longsight', 'Stoke Bishop', 'Hulme',
#        'Stockport  ', 'Hillfields', 'Bury  ', 'Didsbury East',
#        'Trafford  ', 'St George Troopers Hill', 'Baguley', 'Gorton South',
#        'Oldham  ', 'Easton', 'Higher Blackley', 'Horfield',
#        'Bishopsworth', 'Brislington West', 'St George Central', 'Knowle',
#        'St George West', 'Gorton North', 'Brooklands',
#        'Hartcliffe & Withywood', 'Bedminster', 'Chorlton Park', 'Moston',
#        'Crumpsall', 'Southmead', 'Westbury-on-Trym & Henleaze',
#        'Frome Vale', 'Stockwood', 'Lockleaze',
#        'Hengrove & Whitchurch Park', 'Filwood', 'Charlestown',
#        'Woodhouse Park'], dtype=object)

# %%
airbnb_cleaned.WD19NM.unique()  #some areas have been lost (will be readded later)
# Out:
# array(['Ancoats & Beswick', 'Chorlton', 'Cheetham', 'Moss Side',
#        'Withington', 'Didsbury West', 'Old Moat', 'Fallowfield',
#        'Brislington East', 'Eastville', 'Whalley Range', 'Ashley',
#        'Ardwick', 'Clifton Down', 'Central', 'Burnage', 'Redland',
#        'Northenden', 'Rusholme', 'Clifton', 'Cotham', 'Harpurhey',
#        'Windmill Hill', 'Lawrence Hill', 'Levenshulme', 'Sharston',
#        'Southville', 'Longsight', 'Stoke Bishop', 'Hulme', 'Hillfields',
#        'Didsbury East', 'St George Troopers Hill', 'Baguley', 'Easton',
#        'Higher Blackley', 'Horfield', 'Bishopsworth', 'Brislington West',
#        'St George Central', 'Knowle', 'St George West', 'Brooklands',
#        'Bedminster', 'Chorlton Park', 'Moston', 'Crumpsall', 'Southmead',
#        'Frome Vale', 'Stockwood', 'Lockleaze', 'Filwood', 'Charlestown',
#        'Woodhouse Park'], dtype=object)

# %%
airbnb_cleaned.LAD19CD.unique()
# Out:
# array(['E08000003', 'E06000023', 'E08000009'], dtype=object)

# %%
imd=pd.read_csv("data//imd.csv")

# %%
imd=imd.groupby(by='Local Authority District code (2019)').mean().reset_index()

# %%
imd.rename(columns={'Local Authority District code (2019)':'LAD19CD'}, inplace=True)

# %%
#combine dataframe with imd score
airbnb_imd=airbnb_cleaned.merge(imd,on='LAD19CD',how='left')  
#merging on local authority rather than wards since data only available at Local authoriy

# %%
airbnb_imd
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 3241  45009362             Ashley     Bristol  51.47023   -2.57722
# 3242  42525736           Rusholme  Manchester  53.45374   -2.21489
# 3243  28094403             Knowle     Bristol  51.43610   -2.57409
# 3244    390781   Brislington West     Bristol  51.44429   -2.55777
# 3245  31614043           Old Moat  Manchester  53.43804   -2.23831
#
#                   property_type        room_type  accommodates bathrooms  \
# 0              Entire apartment  Entire home/apt            16         3
# 1         Private room in house     Private room            16         3
# 2              Entire apartment  Entire home/apt            16         3
# 3     Private room in apartment     Private room            16         3
# 4         Private room in house     Private room            16         2
# ...                         ...              ...           ...       ...
# 3241  Private room in townhouse     Private room             1         1
# 3242           Entire apartment  Entire home/apt             1         1
# 3243      Private room in house     Private room             1         1
# 3244      Private room in house     Private room             1         1
# 3245      Private room in house     Private room             1         1
#
#       bedrooms  ...  Barriers to Housing and Services Score  \
# 0          4.0  ...                               25.566879
# 1          6.0  ...                               25.566879
# 2          3.0  ...                               25.566879
# 3          6.0  ...                               25.566879
# 4          4.0  ...                               25.566879
# ...        ...  ...                                     ...
# 3241       1.0  ...                               23.226985
# 3242       1.0  ...                               25.566879
# 3243       1.0  ...                               23.226985
# 3244       1.0  ...                               23.226985
# 3245       2.0  ...                               25.566879
#
#       Living Environment Score  \
# 0                    31.629429
# 1                    31.629429
# 2                    31.629429
# 3                    31.629429
# 4                    31.629429
# ...                        ...
# 3241                 22.124901
# 3242                 31.629429
# 3243                 22.124901
# 3244                 22.124901
# 3245                 31.629429
#
#       Income Deprivation Affecting Children Index (IDACI) Score (rate)  \
# 0                                              0.261816
# 1                                              0.261816
# 2                                              0.261816
# 3                                              0.261816
# 4                                              0.261816
# ...                                                 ...
# 3241                                           0.182506
# 3242                                           0.261816
# 3243                                           0.182506
# 3244                                           0.182506
# 3245                                           0.261816
#
#       Income Deprivation Affecting Older People (IDAOPI) Score (rate)  \
# 0                                              0.344681
# 1                                              0.344681
# 2                                              0.344681
# 3                                              0.344681
# 4                                              0.344681
# ...                                                 ...
# 3241                                           0.191049
# 3242                                           0.344681
# 3243                                           0.191049
# 3244                                           0.191049
# 3245                                           0.344681
#
#       Children and Young People Sub-domain Score  \
# 0                                       0.170500
# 1                                       0.170500
# 2                                       0.170500
# 3                                       0.170500
# 4                                       0.170500
# ...                                          ...
# 3241                                    0.311548
# 3242                                    0.170500
# 3243                                    0.311548
# 3244                                    0.311548
# 3245                                    0.170500
#
#       Adult Skills Sub-domain Score Geographical Barriers Sub-domain Score  \
# 0                          0.344784                              -0.559688
# 1                          0.344784                              -0.559688
# 2                          0.344784                              -0.559688
# 3                          0.344784                              -0.559688
# 4                          0.344784                              -0.559688
# ...                             ...                                    ...
# 3241                       0.286110                              -0.420015
# 3242                       0.344784                              -0.559688
# 3243                       0.286110                              -0.420015
# 3244                       0.286110                              -0.420015
# 3245                       0.344784                              -0.559688
#
#      Wider Barriers Sub-domain Score  Indoors Sub-domain Score  \
# 0                           2.733443                  0.507060
# 1                           2.733443                  0.507060
# 2                           2.733443                  0.507060
# 3                           2.733443                  0.507060
# 4                           2.733443                  0.507060
# ...                              ...                       ...
# 3241                        1.927517                  0.266061
# 3242                        2.733443                  0.507060
# 3243                        1.927517                  0.266061
# 3244                        1.927517                  0.266061
# 3245                        2.733443                  0.507060
#
#       Outdoors Sub-domain Score
# 0                      0.449550
# 1                      0.449550
# 2                      0.449550
# 3                      0.449550
# 4                      0.449550
# ...                         ...
# 3241                  -0.042821
# 3242                   0.449550
# 3243                  -0.042821
# 3244                  -0.042821
# 3245                   0.449550
#
# [3246 rows x 47 columns]

# %% [markdown]
# ## Median house data

# %%
#add house price data
med_house=pd.read_csv("data//median_house_ward.csv")
med_house=med_house[['Local authority code','Year ending Jun 2020','Ward name','Local authority name']]

# %%
med_house.rename(columns={'Ward name':'WD19NM'}, inplace=True)

# %%
med_house_filtered=med_house[med_house['Local authority code'].str.contains("|".join(['E08000003', 'E06000023', 'E08000009']))]

# %%
med_house_filtered
# Out:
#      Local authority code Year ending Jun 2020                         WD19NM  \
# 917             E08000003              234,750              Ancoats & Beswick
# 918             E08000003              218,495                        Ardwick
# 919             E08000003              159,475                        Baguley
# 920             E08000003              180,500                     Brooklands
# 921             E08000003              224,000                        Burnage
# ...                   ...                  ...                            ...
# 6350            E06000023              345,000                     Southville
# 6351            E06000023              255,000                      Stockwood
# 6352            E06000023              458,375                   Stoke Bishop
# 6353            E06000023              550,000  Westbury-on-Trym and Henleaze
# 6354            E06000023              317,000                  Windmill Hill
#
#      Local authority name
# 917            Manchester
# 918            Manchester
# 919            Manchester
# 920            Manchester
# 921            Manchester
# ...                   ...
# 6350     Bristol, City of
# 6351     Bristol, City of
# 6352     Bristol, City of
# 6353     Bristol, City of
# 6354     Bristol, City of
#
# [87 rows x 4 columns]

# %%
airbnb_imd_houseprice=airbnb_imd.merge(med_house_filtered, on='WD19NM', how='left')

# %%
airbnb_imd_houseprice
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 3273  45009362             Ashley     Bristol  51.47023   -2.57722
# 3274  42525736           Rusholme  Manchester  53.45374   -2.21489
# 3275  28094403             Knowle     Bristol  51.43610   -2.57409
# 3276    390781   Brislington West     Bristol  51.44429   -2.55777
# 3277  31614043           Old Moat  Manchester  53.43804   -2.23831
#
#                   property_type        room_type  accommodates bathrooms  \
# 0              Entire apartment  Entire home/apt            16         3
# 1         Private room in house     Private room            16         3
# 2              Entire apartment  Entire home/apt            16         3
# 3     Private room in apartment     Private room            16         3
# 4         Private room in house     Private room            16         2
# ...                         ...              ...           ...       ...
# 3273  Private room in townhouse     Private room             1         1
# 3274           Entire apartment  Entire home/apt             1         1
# 3275      Private room in house     Private room             1         1
# 3276      Private room in house     Private room             1         1
# 3277      Private room in house     Private room             1         1
#
#       bedrooms  ...  \
# 0          4.0  ...
# 1          6.0  ...
# 2          3.0  ...
# 3          6.0  ...
# 4          4.0  ...
# ...        ...  ...
# 3273       1.0  ...
# 3274       1.0  ...
# 3275       1.0  ...
# 3276       1.0  ...
# 3277       2.0  ...
#
#       Income Deprivation Affecting Older People (IDAOPI) Score (rate)  \
# 0                                              0.344681
# 1                                              0.344681
# 2                                              0.344681
# 3                                              0.344681
# 4                                              0.344681
# ...                                                 ...
# 3273                                           0.191049
# 3274                                           0.344681
# 3275                                           0.191049
# 3276                                           0.191049
# 3277                                           0.344681
#
#       Children and Young People Sub-domain Score  \
# 0                                       0.170500
# 1                                       0.170500
# 2                                       0.170500
# 3                                       0.170500
# 4                                       0.170500
# ...                                          ...
# 3273                                    0.311548
# 3274                                    0.170500
# 3275                                    0.311548
# 3276                                    0.311548
# 3277                                    0.170500
#
#       Adult Skills Sub-domain Score  Geographical Barriers Sub-domain Score  \
# 0                          0.344784                               -0.559688
# 1                          0.344784                               -0.559688
# 2                          0.344784                               -0.559688
# 3                          0.344784                               -0.559688
# 4                          0.344784                               -0.559688
# ...                             ...                                     ...
# 3273                       0.286110                               -0.420015
# 3274                       0.344784                               -0.559688
# 3275                       0.286110                               -0.420015
# 3276                       0.286110                               -0.420015
# 3277                       0.344784                               -0.559688
#
#       Wider Barriers Sub-domain Score  Indoors Sub-domain Score  \
# 0                            2.733443                  0.507060
# 1                            2.733443                  0.507060
# 2                            2.733443                  0.507060
# 3                            2.733443                  0.507060
# 4                            2.733443                  0.507060
# ...                               ...                       ...
# 3273                         1.927517                  0.266061
# 3274                         2.733443                  0.507060
# 3275                         1.927517                  0.266061
# 3276                         1.927517                  0.266061
# 3277                         2.733443                  0.507060
#
#      Outdoors Sub-domain Score Local authority code  Year ending Jun 2020  \
# 0                     0.449550            E08000003               234,750
# 1                     0.449550            E08000003               325,000
# 2                     0.449550            E08000003               234,750
# 3                     0.449550            E08000003               139,000
# 4                     0.449550            E08000003               145,000
# ...                        ...                  ...                   ...
# 3273                 -0.042821            E06000023               335,000
# 3274                  0.449550            E08000003               164,000
# 3275                 -0.042821            E06000023               297,500
# 3276                 -0.042821            E06000023               275,000
# 3277                  0.449550            E08000003               231,050
#
#       Local authority name
# 0               Manchester
# 1               Manchester
# 2               Manchester
# 3               Manchester
# 4               Manchester
# ...                    ...
# 3273      Bristol, City of
# 3274            Manchester
# 3275      Bristol, City of
# 3276      Bristol, City of
# 3277            Manchester
#
# [3278 rows x 50 columns]

# %%
airbnb_imd_houseprice['bathrooms'].replace({'H':1},inplace=True)
airbnb_imd_houseprice['bathrooms'].replace({'S':1},inplace=True)

# %%
airbnb_imd_houseprice.rename(columns={'Year ending Jun 2020':'Median Price'},inplace=True)

# %%
airbnb_imd_houseprice.drop_duplicates(subset=['id'],inplace=True)

# %%
airbnb_imd_houseprice
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 3273  45009362             Ashley     Bristol  51.47023   -2.57722
# 3274  42525736           Rusholme  Manchester  53.45374   -2.21489
# 3275  28094403             Knowle     Bristol  51.43610   -2.57409
# 3276    390781   Brislington West     Bristol  51.44429   -2.55777
# 3277  31614043           Old Moat  Manchester  53.43804   -2.23831
#
#                   property_type        room_type  accommodates bathrooms  \
# 0              Entire apartment  Entire home/apt            16         3
# 1         Private room in house     Private room            16         3
# 2              Entire apartment  Entire home/apt            16         3
# 3     Private room in apartment     Private room            16         3
# 4         Private room in house     Private room            16         2
# ...                         ...              ...           ...       ...
# 3273  Private room in townhouse     Private room             1         1
# 3274           Entire apartment  Entire home/apt             1         1
# 3275      Private room in house     Private room             1         1
# 3276      Private room in house     Private room             1         1
# 3277      Private room in house     Private room             1         1
#
#       bedrooms  ...  \
# 0          4.0  ...
# 1          6.0  ...
# 2          3.0  ...
# 3          6.0  ...
# 4          4.0  ...
# ...        ...  ...
# 3273       1.0  ...
# 3274       1.0  ...
# 3275       1.0  ...
# 3276       1.0  ...
# 3277       2.0  ...
#
#       Income Deprivation Affecting Older People (IDAOPI) Score (rate)  \
# 0                                              0.344681
# 1                                              0.344681
# 2                                              0.344681
# 3                                              0.344681
# 4                                              0.344681
# ...                                                 ...
# 3273                                           0.191049
# 3274                                           0.344681
# 3275                                           0.191049
# 3276                                           0.191049
# 3277                                           0.344681
#
#       Children and Young People Sub-domain Score  \
# 0                                       0.170500
# 1                                       0.170500
# 2                                       0.170500
# 3                                       0.170500
# 4                                       0.170500
# ...                                          ...
# 3273                                    0.311548
# 3274                                    0.170500
# 3275                                    0.311548
# 3276                                    0.311548
# 3277                                    0.170500
#
#       Adult Skills Sub-domain Score  Geographical Barriers Sub-domain Score  \
# 0                          0.344784                               -0.559688
# 1                          0.344784                               -0.559688
# 2                          0.344784                               -0.559688
# 3                          0.344784                               -0.559688
# 4                          0.344784                               -0.559688
# ...                             ...                                     ...
# 3273                       0.286110                               -0.420015
# 3274                       0.344784                               -0.559688
# 3275                       0.286110                               -0.420015
# 3276                       0.286110                               -0.420015
# 3277                       0.344784                               -0.559688
#
#       Wider Barriers Sub-domain Score  Indoors Sub-domain Score  \
# 0                            2.733443                  0.507060
# 1                            2.733443                  0.507060
# 2                            2.733443                  0.507060
# 3                            2.733443                  0.507060
# 4                            2.733443                  0.507060
# ...                               ...                       ...
# 3273                         1.927517                  0.266061
# 3274                         2.733443                  0.507060
# 3275                         1.927517                  0.266061
# 3276                         1.927517                  0.266061
# 3277                         2.733443                  0.507060
#
#      Outdoors Sub-domain Score Local authority code  Median Price  \
# 0                     0.449550            E08000003       234,750
# 1                     0.449550            E08000003       325,000
# 2                     0.449550            E08000003       234,750
# 3                     0.449550            E08000003       139,000
# 4                     0.449550            E08000003       145,000
# ...                        ...                  ...           ...
# 3273                 -0.042821            E06000023       335,000
# 3274                  0.449550            E08000003       164,000
# 3275                 -0.042821            E06000023       297,500
# 3276                 -0.042821            E06000023       275,000
# 3277                  0.449550            E08000003       231,050
#
#       Local authority name
# 0               Manchester
# 1               Manchester
# 2               Manchester
# 3               Manchester
# 4               Manchester
# ...                    ...
# 3273      Bristol, City of
# 3274            Manchester
# 3275      Bristol, City of
# 3276      Bristol, City of
# 3277            Manchester
#
# [3130 rows x 50 columns]

# %% [markdown]
# # Adding the missing greater manchester data
#
# Greater Manchester has local authorities rather than wards, so it will need some rejigging to fit into the above dataset.

# %%
great_manchester_LAs=greater_manchester_df.neighbourhood_cleansed.unique().tolist() #create list of las in gm

# %%
greater_manchester_la=combined_df[combined_df['neighbourhood_cleansed'].str.contains("|".join(great_manchester_LAs))] #filter out las from combined_df

# %%
greater_manchester_la.neighbourhood_cleansed = greater_manchester_la.neighbourhood_cleansed.str.rstrip()  #remove empty gap
# Out:
# C:\Python36\lib\site-packages\pandas\core\generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
greater_manchester_la.rename(columns={"neighbourhood_cleansed": "LAD19NM"},inplace=True) #change columns to local auithorities
# Out:
# C:\Python36\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
local_authority_single=wards.drop_duplicates(subset=['LAD19NM'])      #keep 1 of each local authoirty
greater_man_wards=greater_manchester_la.merge(local_authority_single, on='LAD19NM')

# %%
greater_man_imd=greater_man_wards.merge(imd,on='LAD19CD',how='left')

# %%
med_price_single=med_house.rename(columns=({'Local authority name':'LAD19NM'}))
med_price_single=med_price_single.drop_duplicates(subset=['LAD19NM'])

# %%
greater_man_imd_medianp=greater_man_imd.merge(med_price_single, on="LAD19NM")

# %%
greater_man_imd_medianp.rename(columns={"LAD19NM": "WD19NM"},inplace=True)  #change it back so we can concatenate

# %%
greater_man_imd_medianp.rename(columns={'Year ending Jun 2020':'Median Price'},inplace=True)

# %%
greater_man_imd_medianp['LAD19NM']=greater_man_imd_medianp['WD19NM']
greater_man_imd_medianp['Local authority name']=greater_man_imd_medianp['WD19NM']

# %%
greater_man_imd_medianp['WD19NM'].unique()
# Out:
# array(['Tameside', 'Rochdale', 'Salford', 'Wigan', 'Bolton', 'Bradford',
#        'Stockport', 'Bury', 'Trafford', 'Oldham'], dtype=object)

# %%
colums_needed=airbnb_imd_houseprice.columns.tolist()
greater_man_cleaned=greater_man_imd_medianp[colums_needed]

# %%
airbnb_imd_houseprice=pd.concat([airbnb_imd_houseprice,greater_man_cleaned])

# %%
airbnb_imd_houseprice.drop_duplicates(subset=['id'],inplace=True)

# %%
airbnb_imd_houseprice['bathrooms'].replace({'H':1},inplace=True)
airbnb_imd_houseprice['bathrooms'].replace({'S':1},inplace=True)
airbnb_imd_houseprice['bathrooms'].replace({'P':1},inplace=True)

# %%
airbnb_imd_houseprice
# Out:
#             id             WD19NM        city  latitude  longitude  \
# 0     27563570  Ancoats & Beswick  Manchester  53.48437   -2.23440
# 1     38428583           Chorlton  Manchester  53.44348   -2.27704
# 2     40700904  Ancoats & Beswick  Manchester  53.48981   -2.23129
# 3     35818838           Cheetham  Manchester  53.50083   -2.24273
# 4     19871804          Moss Side  Manchester  53.45199   -2.24554
# ...        ...                ...         ...       ...        ...
# 1731  43335900             Oldham  Manchester  53.54112   -2.11639
# 1732  31168412             Oldham  Manchester  53.58521   -2.09170
# 1733  31413465             Oldham  Manchester  53.57497   -2.09419
# 1734  42651877             Oldham  Manchester  53.52122   -2.13118
# 1735  30757751             Oldham  Manchester  53.58029   -2.08926
#
#                            property_type        room_type  accommodates  \
# 0                       Entire apartment  Entire home/apt            16
# 1                  Private room in house     Private room            16
# 2                       Entire apartment  Entire home/apt            16
# 3              Private room in apartment     Private room            16
# 4                  Private room in house     Private room            16
# ...                                  ...              ...           ...
# 1731  Private room in serviced apartment     Private room             1
# 1732               Private room in house     Private room             1
# 1733               Private room in house     Private room             1
# 1734           Private room in townhouse     Private room             1
# 1735               Private room in house     Private room             1
#
#      bathrooms  bedrooms  ...  \
# 0            3       4.0  ...
# 1            3       6.0  ...
# 2            3       3.0  ...
# 3            3       6.0  ...
# 4            2       4.0  ...
# ...        ...       ...  ...
# 1731         1       1.0  ...
# 1732         2       1.0  ...
# 1733         1       1.0  ...
# 1734         1       1.0  ...
# 1735         1       1.0  ...
#
#       Income Deprivation Affecting Older People (IDAOPI) Score (rate)  \
# 0                                              0.344681
# 1                                              0.344681
# 2                                              0.344681
# 3                                              0.344681
# 4                                              0.344681
# ...                                                 ...
# 1731                                           0.221241
# 1732                                           0.221241
# 1733                                           0.221241
# 1734                                           0.221241
# 1735                                           0.221241
#
#       Children and Young People Sub-domain Score  \
# 0                                       0.170500
# 1                                       0.170500
# 2                                       0.170500
# 3                                       0.170500
# 4                                       0.170500
# ...                                          ...
# 1731                                    0.264291
# 1732                                    0.264291
# 1733                                    0.264291
# 1734                                    0.264291
# 1735                                    0.264291
#
#       Adult Skills Sub-domain Score  Geographical Barriers Sub-domain Score  \
# 0                          0.344784                               -0.559688
# 1                          0.344784                               -0.559688
# 2                          0.344784                               -0.559688
# 3                          0.344784                               -0.559688
# 4                          0.344784                               -0.559688
# ...                             ...                                     ...
# 1731                       0.402277                               -0.469305
# 1732                       0.402277                               -0.469305
# 1733                       0.402277                               -0.469305
# 1734                       0.402277                               -0.469305
# 1735                       0.402277                               -0.469305
#
#       Wider Barriers Sub-domain Score  Indoors Sub-domain Score  \
# 0                            2.733443                  0.507060
# 1                            2.733443                  0.507060
# 2                            2.733443                  0.507060
# 3                            2.733443                  0.507060
# 4                            2.733443                  0.507060
# ...                               ...                       ...
# 1731                        -1.153610                  0.467752
# 1732                        -1.153610                  0.467752
# 1733                        -1.153610                  0.467752
# 1734                        -1.153610                  0.467752
# 1735                        -1.153610                  0.467752
#
#      Outdoors Sub-domain Score Local authority code  Median Price  \
# 0                     0.449550            E08000003       234,750
# 1                     0.449550            E08000003       325,000
# 2                     0.449550            E08000003       234,750
# 3                     0.449550            E08000003       139,000
# 4                     0.449550            E08000003       145,000
# ...                        ...                  ...           ...
# 1731                  0.136199            E08000004        87,500
# 1732                  0.136199            E08000004        87,500
# 1733                  0.136199            E08000004        87,500
# 1734                  0.136199            E08000004        87,500
# 1735                  0.136199            E08000004        87,500
#
#       Local authority name
# 0               Manchester
# 1               Manchester
# 2               Manchester
# 3               Manchester
# 4               Manchester
# ...                    ...
# 1731                Oldham
# 1732                Oldham
# 1733                Oldham
# 1734                Oldham
# 1735                Oldham
#
# [4855 rows x 50 columns]

# %%
airbnb_imd_houseprice.to_csv('uk_airbnb_cleaned.csv')
